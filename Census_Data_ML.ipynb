# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# %%
adult = fetch_ucirepo(id=2)

X = adult.data.features
y = adult.data.targets
print("Dataset Fetched")
# Out:
# Dataset Fetched

# %%
adult.data.headers
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
adult.variables
# Out:
#               name     role         type      demographic  \
# 0              age  Feature      Integer              Age
# 1        workclass  Feature  Categorical           Income
# 2           fnlwgt  Feature      Integer             None
# 3        education  Feature  Categorical  Education Level
# 4    education-num  Feature      Integer  Education Level
# 5   marital-status  Feature  Categorical            Other
# 6       occupation  Feature  Categorical            Other
# 7     relationship  Feature  Categorical            Other
# 8             race  Feature  Categorical             Race
# 9              sex  Feature       Binary              Sex
# 10    capital-gain  Feature      Integer             None
# 11    capital-loss  Feature      Integer             None
# 12  hours-per-week  Feature      Integer             None
# 13  native-country  Feature  Categorical            Other
# 14          income   Target       Binary           Income
#
# ...

# %%
df_adult = adult.data.original
df_adult
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64               NaN  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# ...

# %%
df_adult.sample()
# Out:
#        age workclass  fnlwgt education  education-num      marital-status  \
# 35431   30   Private  179747   HS-grad              9  Married-civ-spouse
#
#          occupation relationship   race   sex  capital-gain  capital-loss  \
# 35431  Craft-repair      Husband  White  Male             0             0
#
#        hours-per-week native-country income
# 35431              45  United-States  >50K.

# %%
df_adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       47879 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      47876 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  48568 non-null  object
#  14  income          48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df_adult.isnull().head(3)
# Out:
#      age  workclass  fnlwgt  education  education-num  marital-status  \
# 0  False      False   False      False          False           False
# 1  False      False   False      False          False           False
# 2  False      False   False      False          False           False
#
#    occupation  relationship   race    sex  capital-gain  capital-loss  \
# 0       False         False  False  False         False         False
# 1       False         False  False  False         False         False
# 2       False         False  False  False         False         False
#
#    hours-per-week  native-country  income
# 0           False           False   False
# 1           False           False   False
# 2           False           False   False

# %% [markdown]
# ***1. Replace ? to null for the whole dataset***

# %%
df_adult.replace('?', np.nan, inplace=True)
df_adult['income'] = df_adult['income'].str.replace('.', '')

# %% [markdown]
# ***2. Trim leading spaces***

# %%
df_adult = df_adult.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %% [markdown]
# ***3. Fill Occupation and Workclass based on common Income groups. Fill Native country based on most common race for that country***

# %%
common_Occ = df_adult.groupby(['income','native-country'])['occupation'].agg(lambda x: x.mode()[0]).reset_index(name='comm_occupation')
common_wc= df_adult.groupby(['occupation'])['workclass'].agg(lambda x: x.mode()[0]).reset_index(name='comm_workclass')
common_native= df_adult.groupby(['race'])['native-country'].agg(lambda x: x.mode()[0]).reset_index(name='comm_native')

# %%
common_Occ_dict = dict(zip(zip(common_Occ['native-country'], common_Occ['income']), common_Occ['comm_occupation']))
common_wc_dict=dict(zip(common_wc['occupation'], common_wc['comm_workclass']))
common_native_dict=dict(zip(common_native['race'], common_native['comm_native']))

# %%
df_adult['native-country']=df_adult.apply(lambda row: common_native_dict[row['race']] if pd.isna(row['native-country']) else row['native-country'], axis=1)

# %%
df_adult['occupation'] = df_adult.apply(lambda row: common_Occ_dict[(row['native-country'], row['income'])] if pd.isna(row['occupation']) else row['occupation'], axis=1)

# %%
df_adult['workclass'] = df_adult.apply(lambda row: common_wc_dict[row['occupation']] if pd.isna(row['workclass']) else row['workclass'], axis=1)

# %% [markdown]
# ***4. Change  1-12th as 'Did not graduate' and drop column Education Number***

# %%
df_adult.head(3)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
#
#        marital-status         occupation   relationship   race   sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White  Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White  Male
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K

# %%
df_adult['education'] = df_adult['education'].apply(lambda x: 'School' if x == '11th' or x == '7th-8th' or x == '10th'
                                              or x == '5th-6th' or x == '9th' or x == '12th' or x == '1st-4th'
                                              or x == 'Preschool' else x)
df_adult['education'] = df_adult['education'].apply(lambda x: 'Associate' if x == 'Assoc-acdm' or x == 'Assoc-voc' else x)
education_map = {'School':1,
             'HS-grad':2,
             'Some-college':3,
             'Bachelors':4,
             'Prof-school':5,
             'Associate':6,
             'Masters':7,
             'Doctorate':8}
df_adult['education'] = df_adult['education'].map(education_map)

# %%
df_adult.drop(columns=['education-num'], inplace=True)

# %% [markdown]
# ***5. Add column CG_Category 0: No capital gains, 1: capital gains, 2: Undeclared capital gains***

# %%
df_adult['CG_Category'] = np.where(df_adult['capital-gain']==0, 0,
                   np.where(df_adult['capital-gain']==99999 ,2,1))

# %%
df_adult.head(3)
# Out:
#    age         workclass  fnlwgt  education      marital-status  \
# 0   39         State-gov   77516          4       Never-married
# 1   50  Self-emp-not-inc   83311          4  Married-civ-spouse
# 2   38           Private  215646          2            Divorced
#
#           occupation   relationship   race   sex  capital-gain  capital-loss  \
# 0       Adm-clerical  Not-in-family  White  Male          2174             0
# 1    Exec-managerial        Husband  White  Male             0             0
# 2  Handlers-cleaners  Not-in-family  White  Male             0             0
#
#    hours-per-week native-country income  CG_Category
# 0              40  United-States  <=50K            1
# 1              13  United-States  <=50K            0
# 2              40  United-States  <=50K            0

# %% [markdown]
# ***6. Wrote the cleaning to an excel file so that the code above does not need to be run again***

# %%
df_adult.drop_duplicates()
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 0       39         State-gov   77516          4       Never-married
# 1       50  Self-emp-not-inc   83311          4  Married-civ-spouse
# 2       38           Private  215646          2            Divorced
# 3       53           Private  234721          1  Married-civ-spouse
# 4       28           Private  338409          4  Married-civ-spouse
# ...    ...               ...     ...        ...                 ...
# 48837   39           Private  215419          4            Divorced
# 48838   64           Private  321403          2             Widowed
# 48839   38           Private  374983          4  Married-civ-spouse
# 48840   44           Private   83891          4            Divorced
# 48841   35      Self-emp-inc  182148          4  Married-civ-spouse
#
#               occupation    relationship                race     sex  \
# 0           Adm-clerical   Not-in-family               White    Male
# ...

# %%
df_adult.to_excel("Cleaned_Census_Data.xlsx",sheet_name = "Census",index=False)

# %%
df_adult_hist= pd.read_excel('Cleaned_Census_Data.xlsx')

# %% [markdown]
# ***7. Created a histogram with some of the more meaningful dimensions to visualize the spread***

# %%
df_adult_hist.drop(columns=['fnlwgt','native-country','capital-gain','capital-loss','occupation'], inplace=True)

# %%
num_columns = len(df_adult_hist.columns)

num_rows = (num_columns + 1) //2
num_cols = 2

fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(30, 2 * num_rows))

axes = axes.flatten()

for i, column in enumerate(df_adult_hist.columns):
    ax = axes[i]
    df_adult_hist[column].hist(ax=ax, bins=20, color='skyblue', edgecolor='black')
    ax.set_title(f'Distribution of {column}')
    ax.set_xlabel(column)
    ax.set_ylabel('Count')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## ***Univariate Analysis***:  Visualize the distribution of each numerical feature using histograms, box plots, or density plots. Explore categorical features using bar charts to see the frequency of each category

# %%
df_adult_new= pd.read_excel('Cleaned_Census_Data.xlsx')

# %%
plt.figure(figsize=(12, 4))
sns.boxplot(x='workclass', y='age', hue='workclass', data=df_adult_new, palette='Set3')
# Out:
# <Axes: xlabel='workclass', ylabel='age'>

# %%
for workclass in df_adult_new['workclass'].unique().tolist():
    subset = df_adult_new[df_adult_new['workclass'] == workclass]

    sns.kdeplot(data=subset, x='CG_Category', linewidth=3, label=workclass)
# Out:
# C:\Users\teepa\AppData\Local\Temp\ipykernel_16096\105057653.py:4: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=subset, x='CG_Category', linewidth=3, label=workclass)

# %%
df_adult_new['fnl_pct']=(df_adult_new['fnlwgt'] / df_adult_new['fnlwgt'].sum())*100

# %%
df_adult_new.head()
# Out:
#    age         workclass  fnlwgt  education      marital-status  \
# 0   39         State-gov   77516          4       Never-married
# 1   50  Self-emp-not-inc   83311          4  Married-civ-spouse
# 2   38           Private  215646          2            Divorced
# 3   53           Private  234721          1  Married-civ-spouse
# 4   28           Private  338409          4  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country income  CG_Category   fnl_pct
# 0             0              40  United-States  <=50K            1  0.000837
# ...

# %% [markdown]
# ## **Univariate Analysis, Bivariate Analysis, Multivariate Analysis:**

# %%
df_country_wt=df_adult_new.groupby(['native-country','income'])[['fnl_pct','fnlwgt']].sum().reset_index()

# %%
df_country_wt.head(81)
# Out:
#    native-country income    fnl_pct      fnlwgt
# 0        Cambodia  <=50K   0.036103     3344413
# 1        Cambodia   >50K   0.024439     2263879
# 2          Canada  <=50K   0.224729    20817942
# 3          Canada   >50K   0.131394    12171816
# 4           China  <=50K   0.156261    14475397
# ..            ...    ...        ...         ...
# 76  United-States   >50K  22.148004  2051697134
# 77        Vietnam  <=50K   0.147806    13692090
# 78        Vietnam   >50K   0.010815     1001822
# 79     Yugoslavia  <=50K   0.036772     3406394
# 80     Yugoslavia   >50K   0.015995     1481744
#
# [81 rows x 4 columns]

# %%
df_country_wt['income'] = df_country_wt['income'].replace({'<=50K': 50000, '>50K': 10000})

# %%
df_country_wt['native-country'] = df_country_wt['native-country'].replace({'United-States': 'USA'})
df_country_wt['native-country'] = df_country_wt['native-country'].replace({'Dominican-Republic': 'Dominican Republic'})
df_country_wt['native-country'] = df_country_wt['native-country'].replace({'Holand-Netherlands': 'Netherlands'})
df_country_wt['native-country'] = df_country_wt['native-country'].replace({'Outlying-US(Guam-USVI-etc)': 'Puerto Rico'})
df_country_wt['native-country'] = df_country_wt['native-country'].replace({'El-Salvador': 'El Salvador'})
df_country_wt['native-country'] = df_country_wt['native-country'].replace({'Trinadad&Tobago': 'Trinidad and Tobago'})
df_country_wt['native-country'] = df_country_wt['native-country'].replace({'Puerto-Rico': 'Puerto Rico'})

# %%
df_country_wt['native-country'].unique().tolist()
# Out:
# ['Cambodia',
#  'Canada',
#  'China',
#  'Columbia',
#  'Cuba',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'England',
#  'France',
#  'Germany',
#  'Greece',
#  'Guatemala',
#  'Haiti',
#  'Netherlands',
#  'Honduras',
#  'Hong',
#  'Hungary',
#  'India',
#  'Iran',
#  'Ireland',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Laos',
#  'Mexico',
#  'Nicaragua',
#  'Puerto Rico',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Scotland',
#  'South',
#  'Taiwan',
#  'Thailand',
#  'Trinidad and Tobago',
#  'USA',
#  'Vietnam',
#  'Yugoslavia']

# %%
df_country_wt['Wtd_income']=df_country_wt['income']*df_country_wt['fnl_pct']

# %%
import folium

# %%
bins = df_country_wt['fnlwgt'].quantile([0, 0.5, 0.7, 0.9, 1]).tolist()

# %%
bins
# Out:
# [27882.0, 4758229.0, 12171816.0, 21815781.0, 6317016563.0]

# %%
world_geo = r'world_countries.json'

world_map = folium.Map(location=[0, 0], zoom_start=2)

folium.Choropleth(
    geo_data=world_geo,
    data=df_country_wt,
    columns=['native-country', 'fnlwgt'],
    key_on='feature.properties.name',
    fill_color='RdYlGn',
    nan_fill_color="beige",
    fill_opacity=0.9,
    line_opacity=0.2,
    bins=bins).add_to(world_map)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df_adult_new['race'],df_adult_new['hours-per-week'], alpha=0.5, color='blue')
plt.ylabel('hours-per-week')
plt.xlabel('race')
plt.show()

# %%
from sklearn.model_selection import train_test_split
import category_encoders as ce

# %%
X = df_adult_new.drop(['income'], axis=1)

y = df_adult_new['income']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 42)

# %%
X_train.shape, X_test.shape
# Out:
# ((32724, 15), (16118, 15))

# %%
encoder = ce.OrdinalEncoder(cols=['workclass', 'education', 'marital-status', 'relationship', 'race', 'sex','native-country','occupation'])


X_train = encoder.fit_transform(X_train)

X_test = encoder.transform(X_test)

# %%
sns.heatmap(X_train[['hours-per-week', 'sex']].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
column1='hours-per-week'
column2='age'

plt.figure(figsize=(8, 6))
sns.regplot(x=column2, y=column1, data=X_train, scatter_kws={'s': 10}, line_kws={'color': 'red'})
plt.title(f'Pearson Correlation Plot between {column1} and {column2}')
plt.xlabel(column1)
plt.ylabel(column2)
plt.show()

# %%
correlation_matrix = X_train.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %%
int_columns = ['age','fnlwgt','capital-gain','capital-loss','hours-per-week','CG_Category']

# %%
for i in int_columns:
  sns.boxplot(x = df_adult_new[i])
  plt.show()

# %%
Q1 = df_adult_new.age.quantile(0.25)
Q3 = df_adult_new.age.quantile(0.75)
Q1, Q3
# Out:
# (28.0, 48.0)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 20.0

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit, upper_limit
# Out:
# (-2.0, 78.0)

# %%
df_adult_new[(df_adult_new.age<lower_limit)|(df_adult_new.age> upper_limit)]
# Out:
#        age         workclass  fnlwgt  education         marital-status  \
# 74      79           Private  124744          3     Married-civ-spouse
# 222     90           Private   51744          2          Never-married
# 430     80           Private  107762          2                Widowed
# 918     81  Self-emp-not-inc  136063          2     Married-civ-spouse
# 1040    90           Private  137018          2          Never-married
# ...    ...               ...     ...        ...                    ...
# 48524   80           Private  107740          2                Widowed
# 48564   80  Self-emp-not-inc   29441          1  Married-spouse-absent
# 48667   83           Private  192305          3               Divorced
# 48709   79         Local-gov  132668          2     Married-civ-spouse
# 48812   81           Private   26711          6     Married-civ-spouse
#
#               occupation    relationship   race     sex  capital-gain  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[11861   343]
#  [ 2946   968]]
# 0.795942424618439

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=classifier , X=X_train , y=y_train , cv=10)
print('Accuracy: {:.2f} %'.format(accuracies.mean()*100))
print('Standard deviation: {:.2f} %'.format(accuracies.std()*100))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
param_grid = {"C":np.logspace(-3,3,7), "penalty":["l1","l2"]}
grid = RandomizedSearchCV(classifier, param_grid,cv=10, random_state = 0)
grid.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'penalty': 'l2', 'C': 0.001}
# LogisticRegression(C=0.001, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(penalty = 'l2', C=100, random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=100, random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[11861   343]
#  [ 2945   969]]
# 0.7960044670554659

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)

clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
y_pred_gini = clf_gini.predict(X_test)

# %%
print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(y_test, y_pred_gini)))
# Out:
# Model accuracy score with criterion gini index: 0.8304

# %%
education_data = df_adult_new.groupby('education')["income"].count()
education_data = education_data.reset_index()

# %%
plt.figure(figsize = (15,6))
sns.barplot(x = "education", y ="income", data = education_data, palette = "viridis")
plt.show()

# %%
plt.figure(figsize= (13,6))
sns.barplot(x="workclass",y="age", hue="income", data=df_adult_new, palette = "viridis")
plt.xlabel("Workclass")
plt.ylabel("Age")
plt.title("Workclass vs Age by Income")
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='income', hue='occupation', data=df_adult_new, color='red')
# Out:
# <Axes: xlabel='income', ylabel='count'>

# %%
Over50 = df_adult_new[df_adult_new["income"] == '>50K']
df_Over50k = Over50[["sex","income"]].groupby(["sex"]).count().reset_index()
Under50 = df_adult_new[df_adult_new["income"] == '<=50K']
df_Under50k = Under50[["sex","income"]].groupby(["sex"]).count().reset_index()

# %%
plt.figure(figsize = (10,10))
plt.subplot(1,2,1)
plt.pie(x = df_Over50k["income"], labels = ["Female","Male"])
plt.title(">50K")
 
plt.subplot(1,2,2)
plt.pie(x = df_Under50k["income"], labels = ["Female","Male"])
plt.title("<=50K")
plt.show()

# %%
df_No_outliers=df_adult_new[(df_adult_new.age>lower_limit)|(df_adult_new.age< upper_limit)]

# %%
X1 = df_No_outliers.drop(['income'], axis=1)

y1 = df_No_outliers['income']


encoder = ce.OrdinalEncoder(cols=['workclass', 'education', 'marital-status', 'relationship', 'race', 'sex','native-country','occupation'])

X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.33, random_state = 42)

X1_train = encoder.fit_transform(X1_train)

X1_test = encoder.transform(X1_test)

# %%
classifier = LogisticRegression(penalty = 'l2', C=100, random_state = 0)

classifier.fit(X1_train, y1_train)
# Out:
# LogisticRegression(C=100, random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y1_pred = classifier.predict(X1_test)
cm = confusion_matrix(y1_test, y1_pred)
print(cm)
accuracy_score(y1_test, y1_pred)
# Out:
# [[11861   343]
#  [ 2946   968]]
# 0.795942424618439
